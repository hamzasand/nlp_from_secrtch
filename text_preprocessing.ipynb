# %%
import nltk 
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %% [markdown]
# ### Download Required Resources(One time)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\92324\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\92324\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\92324\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
paragraph = """Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.
It helps computers understand human language and perform tasks such as translation, sentiment analysis, and summarization."""

# %%
sentences = sent_tokenize(paragraph)
print('Sentences:', sentences)
# Out:
# Sentences: ['Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.', 'It helps computers understand human language and perform tasks such as translation, sentiment analysis, and summarization.']

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
for sentence in sentences:
    words = word_tokenize(sentence)

    filtered_words =  [w for w in words if w.lower() not in stopwords.words('english') and w.isalpha()]
    print(filtered_words)

    stemmed_words = [stemmer.stem(w) for w in filtered_words]
    lemmatized_words = [lemmatizer.lemmatize(w, pos='v') for w in filtered_words]

    print("Stemmed:", stemmed_words)
    print("Lemmatized:", lemmatized_words)
# Out:
# ['Natural', 'Language', 'Processing', 'NLP', 'fascinating', 'field', 'Artificial', 'Intelligence']
# Stemmed: ['natur', 'languag', 'process', 'nlp', 'fascin', 'field', 'artifici', 'intellig']
# Lemmatized: ['Natural', 'Language', 'Processing', 'NLP', 'fascinate', 'field', 'Artificial', 'Intelligence']
# ['helps', 'computers', 'understand', 'human', 'language', 'perform', 'tasks', 'translation', 'sentiment', 'analysis', 'summarization']
# Stemmed: ['help', 'comput', 'understand', 'human', 'languag', 'perform', 'task', 'translat', 'sentiment', 'analysi', 'summar']
# Lemmatized: ['help', 'computers', 'understand', 'human', 'language', 'perform', 'task', 'translation', 'sentiment', 'analysis', 'summarization']
